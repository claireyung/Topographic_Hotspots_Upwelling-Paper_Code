# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import xarray as xr
import cftime
import glob
import dask
import os
import datetime
import matplotlib.colors as col
import dask.array as dsa
from cosima_cookbook import distributed as ccd
import cartopy.crs as ccrs
import cartopy.feature as cft
import cmocean as cm
import matplotlib.path as mpath

import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)

from dask.distributed import Client

# %%
# this starts up a dask cluster to use all the cores you request:
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:38843' processes=4 threads=12, memory=48.00 GiB>

# %%
session = cc.database.create_session()
# Define experiment in database
expt01 = '01deg_jra55v13_ryf9091'
expt1 = '1deg_jra55_ryf9091_gadi'
# Setting start and end times
start_time = '2170-01-01'
end_time = '2170-12-31'

# %%
vars1 = cc.querying.get_variables(session, experiment=expt01, frequency = '1 daily')
vars1[vars1['name'].str.lower().str.match('')]
# Out:
#                      name                                          long_name  \
# 0              average_DT                           Length of average period
# 1              average_T1                      Start time for average period
# 2              average_T2                        End time for average period
# 3                     dzt                                   t-cell thickness
# 4                   eta_t  surface height on T cells [Boussinesq (volume ...
# 5         frazil_3d_int_z  Vertical sum of ocn frazil heat flux over time...
# 6                     mld   mixed layer depth determined by density criteria
# 7                      nv                                      vertex number
# 8               pme_river  mass flux of precip-evap+river via sbc (liquid...
# 9               pot_rho_1          potential density referenced to 1000 dbar
# 10                   salt                                 Practical Salinity
# 11      sfc_hflux_coupler           surface heat flux coming through coupler
# 12  sfc_hflux_from_runoff  heat flux (relative to 0C) from liquid river r...
# 13          sfc_hflux_pme  heat flux (relative to 0C) from pme transfer o...
# 14         st_edges_ocean                            tcell zstar depth edges
# 15               st_ocean                                  tcell zstar depth
# 16           surface_salt                                 Practical Salinity
# 17           surface_temp                           Conservative temperature
# 18         sw_edges_ocean                            ucell zstar depth edges
# 19               sw_ocean                                  ucell zstar depth
# 20                  tau_x          i-directed wind stress forcing u-velocity
# 21                  tau_y          j-directed wind stress forcing v-velocity
# 22                   temp                           Conservative temperature
# 23                   time                                               time
# 24            time_bounds                               time axis boundaries
# 25                      u                                          i-current
# 26               uhrho_et                   uhrho_et on horz face of T-cells
# 27                  usurf                                  i-surface current
# 28                      v                                          j-current
# 29               vhrho_nt                   vhrho_nt on horz face of T-cells
# 30                  vsurf                                  j-surface current
# 31                     wt                      dia-surface velocity T-points
# 32               xt_ocean                                    tcell longitude
# 33               xu_ocean                                    ucell longitude
# 34               yt_ocean                                     tcell latitude
# 35               yu_ocean                                     ucell latitude
#
#    frequency                                        ncfile  # ncfiles  \
# 0    1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       1288
# 1    1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       1288
# 2    1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       1288
# 3    1 daily        output1115/ocean/ocean_daily_3d_dzt.nc         40
# 4    1 daily               output1115/ocean/ocean_daily.nc        919
# 5    1 daily               output1115/ocean/ocean_daily.nc        894
# 6    1 daily               output1115/ocean/ocean_daily.nc        919
# 7    1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       1288
# 8    1 daily               output1115/ocean/ocean_daily.nc        894
# 9    1 daily  output1115/ocean/ocean_daily_3d_pot_rho_1.nc         40
# 10   1 daily       output1115/ocean/ocean_daily_3d_salt.nc        473
# 11   1 daily               output1115/ocean/ocean_daily.nc        894
# 12   1 daily               output1115/ocean/ocean_daily.nc        894
# 13   1 daily               output1115/ocean/ocean_daily.nc        894
# 14   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc        327
# 15   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       2462
# 16   1 daily               output1115/ocean/ocean_daily.nc        894
# 17   1 daily               output1115/ocean/ocean_daily.nc        919
# 18   1 daily         output1115/ocean/ocean_daily_3d_wt.nc         42
# 19   1 daily         output1115/ocean/ocean_daily_3d_wt.nc        471
# 20   1 daily               output1115/ocean/ocean_daily.nc        172
# 21   1 daily               output1115/ocean/ocean_daily.nc        172
# 22   1 daily       output1115/ocean/ocean_daily_3d_temp.nc        473
# 23   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       3852
# 24   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       3852
# 25   1 daily          output1115/ocean/ocean_daily_3d_u.nc        473
# 26   1 daily   output1115/ocean/ocean_daily_3d_uhrho_et.nc        245
# 27   1 daily               output1115/ocean/ocean_daily.nc        164
# 28   1 daily          output1115/ocean/ocean_daily_3d_v.nc        473
# 29   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc        245
# 30   1 daily               output1115/ocean/ocean_daily.nc        164
# 31   1 daily         output1115/ocean/ocean_daily_3d_wt.nc        471
# 32   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       2906
# 33   1 daily          output1115/ocean/ocean_daily_3d_u.nc       1118
# 34   1 daily   output1115/ocean/ocean_daily_3d_vhrho_nt.nc       2906
# 35   1 daily          output1115/ocean/ocean_daily_3d_u.nc       1118
#
#              time_start             time_end
# 0   1950-01-01 00:00:00  2180-01-01 00:00:00
# 1   1950-01-01 00:00:00  2180-01-01 00:00:00
# 2   1950-01-01 00:00:00  2180-01-01 00:00:00
# 3   2170-01-01 00:00:00  2180-01-01 00:00:00
# 4   1950-01-01 00:00:00  2180-01-01 00:00:00
# 5   1956-04-01 00:00:00  2180-01-01 00:00:00
# 6   1950-01-01 00:00:00  2180-01-01 00:00:00
# 7   1950-01-01 00:00:00  2180-01-01 00:00:00
# 8   1956-04-01 00:00:00  2180-01-01 00:00:00
# 9   2170-01-01 00:00:00  2180-01-01 00:00:00
# 10  1950-01-01 00:00:00  2180-01-01 00:00:00
# 11  1956-04-01 00:00:00  2180-01-01 00:00:00
# 12  1956-04-01 00:00:00  2180-01-01 00:00:00
# 13  1956-04-01 00:00:00  2180-01-01 00:00:00
# 14  1966-01-01 00:00:00  2180-01-01 00:00:00
# 15  1950-01-01 00:00:00  2180-01-01 00:00:00
# 16  1956-04-01 00:00:00  2180-01-01 00:00:00
# 17  1950-01-01 00:00:00  2180-01-01 00:00:00
# 18  1966-01-01 00:00:00  2180-01-01 00:00:00
# 19  1950-01-01 00:00:00  2180-01-01 00:00:00
# 20  2137-01-01 00:00:00  2180-01-01 00:00:00
# 21  2137-01-01 00:00:00  2180-01-01 00:00:00
# 22  1950-01-01 00:00:00  2180-01-01 00:00:00
# 23  1950-01-01 00:00:00  2180-01-01 00:00:00
# 24  1950-01-01 00:00:00  2180-01-01 00:00:00
# 25  1950-01-01 00:00:00  2180-01-01 00:00:00
# 26  1965-01-01 00:00:00  2180-01-01 00:00:00
# 27  2139-01-01 00:00:00  2180-01-01 00:00:00
# 28  1950-01-01 00:00:00  2180-01-01 00:00:00
# 29  1965-01-01 00:00:00  2180-01-01 00:00:00
# 30  2139-01-01 00:00:00  2180-01-01 00:00:00
# 31  1950-01-01 00:00:00  2180-01-01 00:00:00
# 32  1950-01-01 00:00:00  2180-01-01 00:00:00
# 33  1950-01-01 00:00:00  2180-01-01 00:00:00
# 34  1950-01-01 00:00:00  2180-01-01 00:00:00
# 35  1950-01-01 00:00:00  2180-01-01 00:00:00

# %%
# Load velocity fields
v01 = cc.querying.getvar(expt01, 'v', session, ncfile='%daily%', start_time = start_time,end_time=end_time)
v01 = v01.sel(time = '2170-01-01', method = 'nearest')
u01 = cc.querying.getvar(expt01, 'u', session, ncfile='%daily%', start_time = start_time,end_time=end_time)
u01 = u01.sel(time = '2170-01-01', method = 'nearest')

v1 = cc.querying.getvar(expt1, 'v', session, ncfile='ocean.nc', start_time = '2670-01-01',end_time='2670-12-31')
v1 = v1.sel(time = '2670-01-16',method = 'nearest')
u1 = cc.querying.getvar(expt1, 'u', session, ncfile='ocean.nc', start_time = '2670-01-01',end_time='2670-12-31')
u1 = u1.sel(time = '2670-01-16',method = 'nearest')

# %%
speed01 = np.sqrt(v01**2+u01**2)
speed1 = np.sqrt(v1**2+u1**2)

# %%
land_50m = cft.NaturalEarthFeature('physical', 'land', '50m',
                                   edgecolor='black', facecolor='gray', linewidth=0.5)

# %%
# making a nice colormap
cmap = cm.cm.ice
newcmap = cm.tools.crop_by_percent(cmap, 15, which='min', N=None)

# %%
plt.rc('text', usetex=True)
plt.rcParams.update({'font.size': 14})

# %%
# plot a comparison of SS velocity in Southern Ocean
fig = plt.figure(figsize=(10,6))

central_longitude = 155.0
central_latitude = -40.0
satellite_height = 3300000

ax1 = plt.subplot(1, 2, 1, projection=ccrs.NearsidePerspective(central_longitude=central_longitude, central_latitude=central_latitude, satellite_height=satellite_height))
ax1.add_feature(land_50m)
ax1.coastlines(resolution='50m')

p1=speed1.fillna(0).isel(st_ocean = 0).isel(time = 0).plot.pcolormesh(x='xu_ocean', y='yu_ocean', add_colorbar=False,vmin=0,vmax=1.2,cmap=newcmap,transform=ccrs.PlateCarree())

# ax_cb = plt.axes([0.92, 0.25, 0.015, 0.5])
# cb = plt.colorbar(p1, cax=ax_cb, orientation='vertical')
# cb.ax.set_ylabel('SST (°C)');
ax1.set_title('ACCESS-OM2 1$^\circ$ grid', fontsize = 20)
ax2 = plt.subplot(1,2,2,projection=ccrs.NearsidePerspective(central_longitude=central_longitude, central_latitude=central_latitude, satellite_height=satellite_height))
ax2.add_feature(land_50m)
ax2.coastlines(resolution='50m')

p1=speed01.fillna(0).sel(st_ocean = 50, method = 'nearest').isel(time = 0).plot.pcolormesh(x='xu_ocean', y='yu_ocean', add_colorbar=False,vmin=0,vmax=1.2,cmap=newcmap,transform=ccrs.PlateCarree())
ax2.set_title('ACCESS-OM2 0.1$^\circ$ grid',fontsize = 20)

ax_cb = plt.axes([0.92, 0.25, 0.015, 0.5])
cb = plt.colorbar(p1, cax=ax_cb, orientation='vertical')
cb.ax.set_ylabel('Speed (m/s)',fontsize = 18);
cb.ax.tick_params(labelsize=14)
plt.tight_layout()
plt.savefig('model_comparison.png',dpi = 600, transparent = True)

# %%
# plot a comparison of SST in Southern Ocean
fig = plt.figure(figsize=(20,16))

central_longitude = 145.0
central_latitude = -35.0
satellite_height = 10000000

ax1 = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=central_longitude, central_latitude=central_latitude, satellite_height=satellite_height))
ax1.add_feature(land_50m)
ax1.coastlines(resolution='50m')
plott = speed01.sel(st_ocean = 50, method = 'nearest').isel(time = 0)
plott = plott.where(plott!=np.inf).where(plott !=-np.inf).fillna(0)

p1=plott.fillna(0).plot.pcolormesh(x='xu_ocean', y='yu_ocean', add_colorbar=False,vmin=0,vmax=1.2,cmap=newcmap,transform=ccrs.PlateCarree())

#ax_cb = plt.axes([0.85, 0.25, 0.015, 0.5])
#cb = plt.colorbar(p1, cax=ax_cb, orientation='vertical')
#cb.ax.set_ylabel('Speed (m/s)',fontsize = 18);
#cb.ax.tick_params(labelsize=14)
#ax1.set_title('ACCESS-OM2 0.1$^\circ$ grid', fontsize = 20)
ax1.set_title('', fontsize = 20)


plt.savefig('/g/data/x77/cy8964/Honours/video/1degspeed.png',transparent = True, dpi = 400)
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/collections.py in draw(self, renderer)
#    2125         else:
# -> 2126             renderer.draw_quad_mesh(
#    2127                 gc, transform.frozen(), self._meshWidth, self._meshHeight,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_quad_mesh(self, gc, master_transform, meshWidth, meshHeight, coordinates, offsets, offsetTrans, facecolors, antialiased, edgecolors)
#     280
# --> 281         return self.draw_path_collection(
#     282             gc, master_transform, paths, [], offsets, offsetTrans, facecolors,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offsetTrans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#    1973         if (not can_do_optimization) or (not should_do_optimization):
# -> 1974             return RendererBase.draw_path_collection(
#    1975                 self, gc, master_transform, paths, all_transforms,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offsetTrans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#     262                 transform.translate(xo, yo)
# --> 263             self.draw_path(gc0, path, transform, rgbFace)
#     264
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in draw_path(self, gc, path, transform, rgbFace)
#    1926         self.check_gc(gc, rgbFace)
# -> 1927         self.file.writePath(
#    1928             path, transform,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in writePath(self, path, transform, clip, sketch)
#    1782             simplify = False
# -> 1783         cmds = self.pathOperations(path, transform, clip, simplify=simplify,
#    1784                                    sketch=sketch)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in pathOperations(path, transform, clip, simplify, sketch)
#    1767
# -> 1768     @staticmethod
#    1769     def pathOperations(path, transform, clip=None, simplify=None, sketch=None):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ba55d077a349> in <module>
#      22
#      23
# ---> 24 plt.savefig('/g/data/x77/cy8964/Honours/video/1degspeed.pdf',transparent = True, dpi = 1000)
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3003                 patch.set_edgecolor('none')
#    3004
# -> 3005         self.canvas.print_figure(fname, **kwargs)
#    3006
#    3007         if transparent:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2723                 RendererPdf(file, dpi, height, width),
#    2724                 bbox_inches_restore=bbox_inches_restore)
# -> 2725             self.figure.draw(renderer)
#    2726             renderer.finalize()
#    2727             if not isinstance(filename, PdfPages):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2778
#    2779             self.patch.draw(renderer)
# -> 2780             mimage._draw_list_compositing_images(
#    2781                 renderer, self, artists, self.suppressComposite)
#    2782
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     477         self._done_img_factory = True
#     478
# --> 479         return matplotlib.axes.Axes.draw(self, renderer=renderer, **kwargs)
#     480
#     481     def _update_title_position(self, renderer):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# KeyboardInterrupt:

# %%
# want to interpolate this data from one time onto 1 degree grid and then show it for project map slide

speed01_interp = speed01.interp(xu_ocean = speed1.xu_ocean, yu_ocean = speed1.yu_ocean)

fig = plt.figure(figsize=(10,8))

central_longitude = 155.0
central_latitude = -40.0
satellite_height = 3300000

ax1 = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=central_longitude, central_latitude=central_latitude, satellite_height=satellite_height))
ax1.add_feature(land_50m)
ax1.coastlines(resolution='50m')

p1=speed01_interp.fillna(0).sel(st_ocean = 50, method = 'nearest').isel(time = 0).plot.pcolormesh(x='xu_ocean', y='yu_ocean', add_colorbar=False,vmin=0,vmax=1.2,cmap=newcmap,transform=ccrs.PlateCarree())

# ax_cb = plt.axes([0.85, 0.25, 0.015, 0.5])
# cb = plt.colorbar(p1, cax=ax_cb, orientation='vertical')
# cb.ax.set_ylabel('Speed (m/s)',fontsize = 18);
# cb.ax.tick_params(labelsize=14)
# ax1.set_title('ACCESS-OM2 0.1$^\circ$ grid', fontsize = 20)
ax1.set_title('', fontsize = 20)


plt.savefig('video/0.1degspeedinterp.png',transparent = True, dpi = 400)

# %% [markdown]
# # Animate this speed for 0.1 degree model
# using code from
# https://climate-cms.org/2019/09/03/python-animation.html

# %%
v01 = cc.querying.getvar(expt01, 'v', session, ncfile='%daily%', start_time = start_time,end_time=end_time)
v01 = v01.sel(time = slice('2170-01-01','2170-12-31'))
u01 = cc.querying.getvar(expt01, 'u', session, ncfile='%daily%', start_time = start_time,end_time=end_time)
u01 = u01.sel(time = slice('2170-01-01','2170-12-31'))

speed01 = np.sqrt(v01**2+u01**2)

# %%
from matplotlib import pyplot as plt, animation
# %matplotlib inline

# This is needed to display graphics calculated outside of jupyter notebook
from IPython.display import HTML, display

# %%
# this is to make sure there is no size limit
import matplotlib

matplotlib.rcParams['animation.embed_limit'] = 2**128

# %%
# Get a handle on the figure and the axes

# Plot the initial frame. 

fig = plt.figure(figsize=(10,8))

central_longitude = 155.0
central_latitude = -40.0
satellite_height = 3300000

ax1 = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=central_longitude, central_latitude=central_latitude, satellite_height=satellite_height))
ax1.add_feature(land_50m)
ax1.coastlines(resolution='50m')

cax=speed01[0,:,:].fillna(0).sel(st_ocean = 100, method = 'nearest').plot.pcolormesh(x='xu_ocean', y='yu_ocean', add_colorbar=False,vmin=0,vmax=1.2,cmap=newcmap,transform=ccrs.PlateCarree())

ax_cb = plt.axes([0.85, 0.25, 0.015, 0.5])
cb = plt.colorbar(p1, cax=ax_cb, orientation='vertical')
cb.ax.set_ylabel('Speed (m/s)',fontsize = 18);
cb.ax.tick_params(labelsize=14)
ax1.set_title('')

# Next we need to create a function that updates the values for the colormesh, as well as the title.
def animate(frame):
    cax.set_array(speed01[frame,:,:].fillna(0).sel(st_ocean = 100, method = 'nearest').values.flatten())
    ax1.set_title("ACCESS-OM2 0.1$^\circ$ grid   Day " + str(frame),fontsize = 20)

# Finally, we use the animation module to create the animation.
ani = animation.FuncAnimation(
    fig,             # figure
    animate,         # name of the function above
    frames=365,       # Could also be iterable or list
    interval=50     # ms between frames
)

# %%
#turn it into playable HTML
#HTML(ani.to_jshtml())

# %%
#save!
ani.save('/g/data/x77/cy8964/Honours/video/speed_01v2.mp4',dpi = 300)
display(HTML("<video controls><source src='/g/data/x77/cy8964/Honours/video/speed_01.mp4' type='video/mp4'></video>"))
# Out:
# <video controls><source src='/g/data/x77/cy8964/Honours/video/speed_01.mp4' type='video/mp4'></video>
